# %%
import pydss

# %%
sys_carlos = pydss.pydss('cigre_lv_isolated_3gformers.json')

# %%
sys_carlos.pf_eval()

# %%
sys_carlos.I_node
# Out:
# array([[  8.70011502e+01 -9.98096244e+01j],
#        [ -1.30306478e+02 -2.56634542e+01j],
#        [  4.33793374e+01 +1.25853870e+02j],
#        [ -7.40097394e-02 -3.80791596e-01j],
#        [  5.72244488e+01 -6.03445464e+01j],
#        [ -8.02843378e+01 -1.90867995e+01j],
#        [  2.30587666e+01 +7.87574278e+01j],
#        [  1.12242709e-03 +6.73918119e-01j],
#        [  1.02394065e+02 -1.15065742e+02j],
#        [ -1.50921062e+02 -3.12166046e+01j],
#        [  4.86005205e+01 +1.46325961e+02j],
#        [ -7.35236881e-02 -4.36139155e-02j],
#        [ -4.81982865e+01 +5.39259369e+01j],
#        [  7.07828651e+01 +1.47779617e+01j],
#        [ -2.26020413e+01 -6.86736069e+01j],
#        [  1.74626846e-02 -3.02916536e-02j],
#        [ -1.44978647e+01 +1.62011889e+01j],
#        [  2.12740571e+01 +4.45474139e+00j],
#        [ -6.78196263e+00 -2.06465717e+01j],
#        [  5.77022947e-03 -9.35862940e-03j],
#        [ -5.05406698e+01 +5.63177774e+01j],
# ...
