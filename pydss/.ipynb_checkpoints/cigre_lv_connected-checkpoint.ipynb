# %%
import numpy as np
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
from bokeh.layouts import gridplot
from bokeh.models import ColumnDataSource, HoverTool, CustomJS
from bokeh.io import push_notebook
from ipywidgets import interact
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="89156686-efe6-43a7-b3c4-ea97078eba21">Loading BokehJS ...</span>
#     </div>

# %%
import pydss

# %% [markdown]
# ## CIGRE LV European System

# %%
sys1 = pydss.pydss('cigre_lv.json')  # Load data
sys1.pf()                            # execute power flow

# %%
sys1.get_v()      # post process voltages
sys1.get_i()      # post process currents

# %% [markdown]
# ### Graph with obtained results

# %%
sys1.bokeh_tools()

p = figure(width=600, height=800,
           title='European LV Network (CIGRE)', 
           x_range=[-200,200], y_range=[-350, 50])

# lines:
source = ColumnDataSource(sys1.line_data)
lin = p.multi_line(source=source, xs='x_s', ys='y_s', color="red", alpha=0.5, line_width=5)

# buses:
source = ColumnDataSource(sys1.bus_data)
cr = p.circle(source=source, x='x', y='y', size=15, color="navy", alpha=0.5)

p.add_tools(HoverTool(renderers=[lin], tooltips=sys1.line_tooltip))
p.add_tools(HoverTool(renderers=[cr], tooltips=sys1.bus_tooltip))
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2e999619-bf7c-493d-9423-db56286d2dbf"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("2e999619-bf7c-493d-9423-db56286d2dbf");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2e999619-bf7c-493d-9423-db56286d2dbf");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2e999619-bf7c-493d-9423-db56286d2dbf' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"440bd92f-991c-4513-9057-fc71705a3ad6":{"roots":{"references":[{"attributes":{"below":[{"id":"8fd6e2eb-fe7c-42a0-aa72-ebe068619cc7","type":"LinearAxis"}],"left":[{"id":"bab23b98-0cf1-4624-91ab-f5ab8b5130cf","type":"LinearAxis"}],"plot_height":800,"renderers":[{"id":"8fd6e2eb-fe7c-42a0-aa72-ebe068619cc7","type":"LinearAxis"},{"id":"1b515aa1-66a7-4321-837c-41193a09e98d","type":"Grid"},{"id":"bab23b98-0cf1-4624-91ab-f5ab8b5130cf","type":"LinearAxis"},{"id":"0453eee3-1154-4143-a3d5-b949cddc4431","type":"Grid"},{"id":"cab87a4b-6183-483a-b3eb-c7001ae646cf","type":"BoxAnnotation"},{"id":"091473ee-c3d2-4444-8c0a-04ba6b06f97e","type":"GlyphRenderer"},{"id":"3a9bd38f-1917-4a59-83d0-62c55ccf29aa","type":"GlyphRenderer"}],"title":{"id":"9cf331d5-2d3d-459d-905e-1cd2241ea7f7","type":"Title"},"tool_events":{"id":"d8947a96-9f9a-43b3-9724-8df05d89bbb9","type":"ToolEvents"},"toolbar":{"id":"acaca0c9-e0c4-4b95-aacd-b219c66b4436","type":"Toolbar"},"x_range":{"id":"f04572f8-eb03-44e0-84c5-2180f1287247","type":"Range1d"},"x_scale":{"id":"64a0d792-2ed0-4681-8993-a4a45559c0f0","type":"LinearScale"},"y_range":{"id":"5230428c-3b5b-48ec-bf0f-7f532316ae85","type":"Range1d"},"y_scale":{"id":"32b01d41-812d-4b5d-bc96-2de4c16bb748","type":"LinearScale"}},"id":"cd4f1f3f-2fed-4cbd-9fb4-b9ffeb6b4882","subtype":"Figure","type":"Plot"},{"attributes":{"formatter":{"id":"0e907072-b8fe-4b93-b978-8c12f38b8855","type":"BasicTickFormatter"},"plot":{"id":"cd4f1f3f-2fed-4cbd-9fb4-b9ffeb6b4882","subtype":"Figure","type":"Plot"},"ticker":{"id":"37a1adbc-51fb-4dfe-a300-3de4b59d007a","type":"BasicTicker"}},"id":"bab23b98-0cf1-4624-91ab-f5ab8b5130cf","type":"LinearAxis"},{"attributes":{},"id":"32b01d41-812d-4b5d-bc96-2de4c16bb748","type":"LinearScale"},{"attributes":{"plot":null,"text":"European LV Network (CIGRE)"},"id":"9cf331d5-2d3d-459d-905e-1cd2241ea7f7","type":"Title"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":5},"xs":{"field":"x_s"},"ys":{"field":"y_s"}},"id":"5f77e7a6-c571-4a97-ba73-3c74192690d4","type":"MultiLine"},{"attributes":{"callback":null,"plot":{"id":"cd4f1f3f-2fed-4cbd-9fb4-b9ffeb6b4882","subtype":"Figure","type":"Plot"},"renderers":[{"id":"3a9bd38f-1917-4a59-83d0-62c55ccf29aa","type":"GlyphRenderer"}],"tooltips":"\n            <div>\n            bus_id = @bus_id \n            <table border=\"1\">\n                <tr>\n                <td>v<sub>an</sub> =  @v_an  &ang; @deg_an V </td> <td> S<sub>a</sub> = @p_a + j@q_a </td>\n                </tr>\n                      <tr>\n                      <td> </td> <td>v<sub>ab</sub>= @v_ab V</td>\n                      </tr>\n                <tr>\n                <td>v<sub>bn</sub> = @v_bn &ang; @deg_bn V </td><td> S<sub>b</sub> = @p_b + j@q_b </td>\n                </tr>\n                      <tr>\n                      <td> </td><td>v<sub>bc</sub>= @v_bc V</td>\n                      </tr>\n                <tr>\n                <td>v<sub>cn</sub>  = @v_cn &ang; @deg_cn V </td>  <td>S<sub>c</sub> = @p_c + j@q_c </td>\n                </tr> \n                    <tr>\n                     <td> </td> <td>v<sub>ca</sub>= @v_ca V</td>\n                    </tr>\n               <tr>\n                <td>v<sub>ng</sub>    = @v_ng &ang; @deg_ng V</td>  <td>S<sub>abc</sub> = @p_abc + j@q_abc </td>\n              </tr>\n            </table>\n            </div>\n            "},"id":"cf458390-0c6a-400e-a090-5b10efcdeed6","type":"HoverTool"},{"attributes":{"callback":null,"column_names":["y","p_a","v_an","q_a","q_c","v_bc","v_ng","v_ab","q_b","q_abc","v_bn","deg_ng","p_c","v_ca","deg_an","p_b","deg_cn","deg_bn","x","bus_id","p_abc","v_cn"],"data":{"bus_id":["R0","R1","R2","R3","R4","R5","R6","R7","R8","R9","R10","R11","R12","R13","R14","R15","R16","R17","R18"],"deg_an":[0.0,-1.7049066077581716,-1.7256647557383757,-1.746871828355965,-1.7669763868712485,-1.7805711777140802,-1.7943684970622507,-1.8025156794206831,-1.8107365738895136,-1.81903218 ...

# %% [markdown]
# ### Interaction with powers

# %%
p = figure(width=600, height=300,
           title='Voltage vs load powers', 
           x_range = [50,-300], y_range = [180,250],
           x_axis_label='Distance (m)',
           y_axis_label='Voltage (V)')
source = ColumnDataSource(sys1.bus_data)
cr = p.circle(source=source, x='y', y='v_an', size=15, color="red", alpha=0.5)
p.circle(source=source, x='y', y='v_bn', size=15, color="green", alpha=0.5)
p.circle(source=source, x='y', y='v_cn', size=15, color="blue", alpha=0.5)
p.line([-300, 50],[231*1.05,231*1.05], color='red', line_width=5)
p.line([-300, 50],[231*0.90,231*0.90], color='blue', line_width=5)
#p.add_tools(HoverTool(renderers=[cr], tooltips=sys1.bus_tooltip))


def update(load_factor=1.0):

    sys1.pq_3pn = load_factor*s_0
    sys1.pf()
    sys1.get_v()
    sys1.get_i()
    sys1.bokeh_tools()

    source.data = sys1.bus_data
    push_notebook()

#p_grid = gridplot([[p], [p_2]])
show(p, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4539c6b9-81a8-4d85-b5ed-c826efc965ea"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("4539c6b9-81a8-4d85-b5ed-c826efc965ea");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("340e5c4d-b4c0-4a7b-993a-13afb26b82fe", function () {});
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4539c6b9-81a8-4d85-b5ed-c826efc965ea");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4539c6b9-81a8-4d85-b5ed-c826efc965ea' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"28ff4ccb-a5b8-4406-a4fc-c73032fca43f":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"b91c2ddb-f1b8-4e43-8d1c-a898db20d87d","type":"Line"},{"attributes":{"plot":{"id":"a3d141b4-c2ef-4f1f-a19e-882b1b52d856","subtype":"Figure","type":"Plot"}},"id":"d18752e3-753e-4520-9fbf-248f7835da6d","type":"HelpTool"},{"attributes":{"plot":{"id":"a3d141b4-c2ef-4f1f-a19e-882b1b52d856","subtype":"Figure","type":"Plot"}},"id":"84182c64-edaa-40c5-bed9-7415c424f341","type":"PanTool"},{"attributes":{"plot":null,"text":"Voltage vs load powers"},"id":"3c69b376-2d8b-41c0-9915-d8fbebb1c88e","type":"Title"},{"attributes":{"plot":{"id":"a3d141b4-c2ef-4f1f-a19e-882b1b52d856","subtype":"Figure","type":"Plot"}},"id":"aebb3bbd-bd1f-4c39-8992-2d4d3346e113","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"b18f4646-9a51-48c1-862a-c48023005785","type":"ColumnDataSource"},"glyph":{"id":"1c52bd8c-9068-41a3-991c-f87be3f6a658","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"d234f979-966b-4b62-aa54-948e19bcbfe6","type":"Circle"},"selection_glyph":null},"id":"94f5f071-3bd7-4b2f-ad9f-581a608e9105","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"a3d141b4-c2ef-4f1f-a19e-882b1b52d856","subtype":"Figure","type":"Plot"},"ticker":{"id":"c6153c38-2e73-48dd-a664-4fcc70331879","type":"BasicTicker"}},"id":"bf2233ac-3d51-400f-a01b-3c90dfb7f642","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":15},"x":{"field":"y"},"y":{"field":"v_cn"}},"id":"a285d3c5-3c80-4809-8b82-9679c1bca1c8","type":"Circle"},{"attributes":{},"id":"057588ac-5824-4eaa-b61e-eff1c33f6f0c","type":"ToolEvents"},{"attributes":{"line_color":{"value":"red"},"line_width":{"value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"0bd2d877-4a15-4cc7-ae14-eae1313f6cd9","type":"Line"},{"attributes":{},"id":"30e402b5-994e-4eb1-bf63-5f914eca7678","type":"BasicTicker"},{"attributes":{"data_source":{"id":"f5641706-1d12-43dd-89b2-f4e54339b57c","type":"ColumnDataSource"},"glyph":{"id":"0bd2d877-4a15-4cc7-ae14-eae1313f6cd9","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"8f711a12-109e-4385-9205-3056a77523db","type":"Line"},"selection_glyph":null},"id":"d6aea0d6-062e-448d-b2f6-8f81a8afc7fd","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"b18f4646-9a51-48c1-862a-c48023005785","type":"ColumnDataSource"},"glyph":{"id":"d1f4a347-6eb3-495b-a824-36be358e6e83","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"aad18c7c-271f-4732-bf9b-9a56995732d5","type":"Circle"},"selection_glyph":null},"id":"c7036710-9ebb-4a42-bb62-d32ad3c6a1c7","type":"GlyphRenderer"},{"attributes":{"callback":null,"end":250,"start":180},"id":"ddf2978a-5fa6-4ea6-a0f5-88d9e27c6911","type":"Range1d"},{"attributes":{"below":[{"id":"93f3404f-8aeb-4a40-a856-d56005858344","type":"LinearAxis"}],"left":[{"id":"7bf615bd-f428-49a3-b2eb-c24319379cba","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"93f3404f-8aeb-4a40-a856-d56005858344","type":"LinearAxis"},{"id":"bf2233ac-3d51-400f-a01b-3c90dfb7f642","type":"Grid"},{"id":"7bf615bd-f428-49a3-b2eb-c24319379cba","type":"LinearAxis"},{"id":"69c05548-bb40-4ece-8168-9dd2a1bcb5aa","type":"Grid"},{"id":"1a18860d-b44a-49e2-a815-9e1fe08d72be","type":"BoxAnnotation"},{"id":"c7036710-9ebb-4a42-bb62-d32ad3c6a1c7","type":"GlyphRenderer"},{"id":"94f5f071-3bd7-4b2f-ad9f-581a608e9105","type":"GlyphRenderer"},{"id":"a85a1882-98cd-45c9-9cb1-140f9e8193a7","type":"GlyphRenderer"},{"id":"d6aea0d6-062e-448d-b2f6-8f81a8afc7fd","type":"GlyphRenderer"},{"id":"3c466ad7-d4fc-4ba2-8f7b-45afe9fb07a0","type":"GlyphRenderer"}],"title":{"id":"3c69b376-2d8b-41c0-9915-d8fbebb1c88e","type":"Title"},"tool_events":{"id":"057588ac-5824-4eaa-b61e-eff1c33f6f0 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[6]</strong>&gt;</code></p>

# %%
from ipywidgets import interact
interact(update, load_factor=(-1,1.2, 0.01))
# Out:
# <function __main__.update>

# %% [markdown]
# ### Interaction with compensator currents

# %%
p = figure(width=600, height=400,
           title='Voltage with compensation', 
           x_range = [50,-300], y_range = [180,250],
           x_axis_label='Distance (m)',
           y_axis_label='Voltage (V)')
source = ColumnDataSource(sys1.bus_data)

i_a_0 = np.abs(sys1.I_node[28,0])
i_b_0 = np.abs(sys1.I_node[29,0])
i_c_0 = np.abs(sys1.I_node[30,0])
s_0 = sys1.pq_3pn # 

sys1.pf()

cr = p.circle(source=source, x='y', y='v_an', size=15, color="red", alpha=0.5)
p.circle(source=source, x='y', y='v_bn', size=15, color="green", alpha=0.5)
p.circle(source=source, x='y', y='v_cn', size=15, color="blue", alpha=0.5)
p.line([-300, 50],[231*1.05,231*1.05], color='red', line_width=5)
p.line([-300, 50],[231*0.90,231*0.90], color='blue', line_width=5)
#p.add_tools(HoverTool(renderers=[cr], tooltips=sys1.bus_tooltip))

def update(i_a=0.0,i_b=0.0,i_c=0.0):

    sys1.I_node[28,0] = (i_a + i_a_0)*np.exp(1j*np.angle(sys1.V_node[28,0] -np.pi/2 ))
    sys1.I_node[29,0] = (i_b + i_b_0)*np.exp(1j*np.angle(sys1.V_node[29,0] -np.pi/2 ))
    sys1.I_node[30,0] = (i_c + i_c_0)*np.exp(1j*np.angle(sys1.V_node[30,0] -np.pi/2 ))    
    sys1.pf()
    sys1.get_v()
    sys1.get_i()
    sys1.bokeh_tools()

    source.data = sys1.bus_data
    push_notebook()

show(p, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="aeffcb85-1a4d-4807-9d14-32913bc4f8b8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#aeffcb85-1a4d-4807-9d14-32913bc4f8b8").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("cc4ddf2d-ac76-4665-8aa9-a5db587d71de", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("aeffcb85-1a4d-4807-9d14-32913bc4f8b8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'aeffcb85-1a4d-4807-9d14-32913bc4f8b8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"8a6ccbf0-c62a-40a0-b1b2-9632cc0fbb3f":{"roots":{"references":[{"attributes":{"axis_label":"Voltage (V)","formatter":{"id":"d4fb1532-6457-4cc1-afaf-7411124e7ccc","type":"BasicTickFormatter"},"plot":{"id":"e880cf46-54db-4038-8198-897be2d55cdc","subtype":"Figure","type":"Plot"},"ticker":{"id":"744536ae-b5b9-43c1-9944-c9d6c6b06525","type":"BasicTicker"}},"id":"b1c15cb8-829a-42e2-af36-532c8b405ffd","type":"LinearAxis"},{"attributes":{"data_source":{"id":"1912dede-208f-4add-9587-0c16943fd76c","type":"ColumnDataSource"},"glyph":{"id":"9481e658-7d8a-41c8-8e42-bbb2026547cd","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"db8f3e43-24b9-4ccf-beb9-77e0581013c1","type":"Circle"},"selection_glyph":null},"id":"052f385e-5d0b-4e69-8868-6a093598e489","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"165775c5-b3c5-440b-8e0a-c7ca854d7f75","type":"BoxAnnotation"},"plot":{"id":"e880cf46-54db-4038-8198-897be2d55cdc","subtype":"Figure","type":"Plot"}},"id":"8ed40e40-6d1b-4968-aa1c-2df430c924e7","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[-300,50],"y":[207.9,207.9]}},"id":"a526b74d-a22c-4b71-a03a-265380207118","type":"ColumnDataSource"},{"attributes":{"axis_label":"Distance (m)","formatter":{"id":"426421d1-d079-4ab2-89f7-e31c180c3c48","type":"BasicTickFormatter"},"plot":{"id":"e880cf46-54db-4038-8198-897be2d55cdc","subtype":"Figure","type":"Plot"},"ticker":{"id":"97d021f6-7c16-4ddc-b4f0-e8106147a6e9","type":"BasicTicker"}},"id":"10407c45-a098-4ec2-998c-1a0726f94eae","type":"LinearAxis"},{"attributes":{"plot":{"id":"e880cf46-54db-4038-8198-897be2d55cdc","subtype":"Figure","type":"Plot"}},"id":"cfa99f14-b6bb-4d17-abc2-a4218d1c1184","type":"SaveTool"},{"attributes":{},"id":"426421d1-d079-4ab2-89f7-e31c180c3c48","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"e880cf46-54db-4038-8198-897be2d55cdc","subtype":"Figure","type":"Plot"},"ticker":{"id":"744536ae-b5b9-43c1-9944-c9d6c6b06525","type":"BasicTicker"}},"id":"42d2e489-e621-4be8-af12-524ca12dab2c","type":"Grid"},{"attributes":{"data_source":{"id":"1912dede-208f-4add-9587-0c16943fd76c","type":"ColumnDataSource"},"glyph":{"id":"3e100276-996d-451f-85e5-6fff7ace9aaa","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"a1145308-5eab-4219-898b-baabbf9505d9","type":"Circle"},"selection_glyph":null},"id":"b18db160-106d-44bd-9f34-062438149b4a","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"e880cf46-54db-4038-8198-897be2d55cdc","subtype":"Figure","type":"Plot"}},"id":"b1e6bc12-0499-4a2b-9bb1-227b65823f5b","type":"PanTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"593a05e0-e526-4daf-93a2-2956a6c51fad","type":"Line"},{"attributes":{"callback":null,"end":-300,"start":50},"id":"7c1cf262-244e-45af-bf02-59533bb3ea96","type":"Range1d"},{"attributes":{"plot":null,"text":"Voltage with compensation"},"id":"4b681969-76f9-4d08-b12f-49010a954160","type":"Title"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":15},"x":{"field":"y"},"y":{"field":"v_cn"}},"id":"db8f3e43-24b9-4ccf-beb9-77e0581013c1","type":"Circle"},{"attributes":{},"id":"d4fb1532-6457-4cc1-afaf-7411124e7ccc","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"e880cf46-54db-4038-8198-897be2d55cdc","subtype":"Figure","type":"Plot"},"ticker":{"id":"97d021f6-7c16-4ddc-b4f0-e8106147a6e9","type":"BasicTicker"}},"id":"c0c62c9a-aa68-4012-8c7b-6acdbf129939","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"165775c5-b3c5-440b- ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[26]</strong>&gt;</code></p>

# %%
interact(update, 
         i_a=(-100,100, 1),
         i_b=(-100,100, 1),
         i_c=(-100,100, 1))
