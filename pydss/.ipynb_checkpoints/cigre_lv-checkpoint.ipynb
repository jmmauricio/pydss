# %%
import pydss
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
from bokeh.layouts import gridplot
from bokeh.models import ColumnDataSource, HoverTool, CustomJS
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e349abe4-864e-4e52-be69-fd4e6bf98b8e">Loading BokehJS ...</span>
#     </div>

# %%
sys1 = pydss.pydss('cigre_lv.json')
sys1.pf()

# %%
sys1.get_v()
sys1.get_i()

# %%
sys1.bokeh_tools()

p = figure(width=600, height=800,
           title='European LV Network (CIGRE)', 
           x_range=[-200,200], y_range=[-350, 50])

# lines:
source = ColumnDataSource(sys1.line_data)
lin = p.multi_line(source=source, xs='x_s', ys='y_s', color="red", alpha=0.5, line_width=5)

# buses:
source = ColumnDataSource(sys1.bus_data)
cr = p.circle(source=source, x='x', y='y', size=15, color="navy", alpha=0.5)

p.add_tools(HoverTool(renderers=[lin], tooltips=sys1.line_tooltip))
p.add_tools(HoverTool(renderers=[cr], tooltips=sys1.bus_tooltip))
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="df93b94b-ace2-48e0-b472-02a959c77630"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#df93b94b-ace2-48e0-b472-02a959c77630").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("df93b94b-ace2-48e0-b472-02a959c77630");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'df93b94b-ace2-48e0-b472-02a959c77630' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"4d4f19cf-d4ea-44a4-be0c-68bca9e10480":{"roots":{"references":[{"attributes":{"plot":{"id":"44cf6729-e1f4-486a-bd23-1f1da3cb2882","subtype":"Figure","type":"Plot"}},"id":"df9326aa-9432-4503-87cb-8ab7f8734b11","type":"SaveTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":15},"x":{"field":"x"},"y":{"field":"y"}},"id":"9b764b20-adf8-4b6c-94b5-1ad76709a6bc","type":"Circle"},{"attributes":{"plot":{"id":"44cf6729-e1f4-486a-bd23-1f1da3cb2882","subtype":"Figure","type":"Plot"}},"id":"0e15b485-a58a-41d7-be75-373b21ff4b13","type":"ResetTool"},{"attributes":{"below":[{"id":"552b3255-a1a6-457e-a42e-3e862268e91c","type":"LinearAxis"}],"left":[{"id":"f2780bfc-d3e6-4e98-8e22-7dc2ead4442a","type":"LinearAxis"}],"plot_height":800,"renderers":[{"id":"552b3255-a1a6-457e-a42e-3e862268e91c","type":"LinearAxis"},{"id":"2c858a70-5a8b-4238-bde0-6cb40b82bd22","type":"Grid"},{"id":"f2780bfc-d3e6-4e98-8e22-7dc2ead4442a","type":"LinearAxis"},{"id":"8ca24bfb-3c2f-4796-84e7-a8a57046fea5","type":"Grid"},{"id":"4aaa68b9-6fdd-483c-91bb-63f0dfce863c","type":"BoxAnnotation"},{"id":"af265a18-e47f-4bf4-bb9b-c2ccebecbd42","type":"GlyphRenderer"},{"id":"0f11de14-ac97-43a3-80ef-6c13c409a52c","type":"GlyphRenderer"}],"title":{"id":"c782d435-1b76-4a34-8c86-2920219ad9e3","type":"Title"},"tool_events":{"id":"ddb52d2b-cfb1-4334-9deb-e38fa131d52e","type":"ToolEvents"},"toolbar":{"id":"26010c26-677d-4e3d-a66a-648ccd18ab19","type":"Toolbar"},"x_range":{"id":"bd0da9db-88a6-43e6-b29a-f239654fcddc","type":"Range1d"},"y_range":{"id":"298aa911-812b-4321-89f8-3e040a616ab1","type":"Range1d"}},"id":"44cf6729-e1f4-486a-bd23-1f1da3cb2882","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"ddb52d2b-cfb1-4334-9deb-e38fa131d52e","type":"ToolEvents"},{"attributes":{"overlay":{"id":"4aaa68b9-6fdd-483c-91bb-63f0dfce863c","type":"BoxAnnotation"},"plot":{"id":"44cf6729-e1f4-486a-bd23-1f1da3cb2882","subtype":"Figure","type":"Plot"}},"id":"3cf0bd48-d1ab-47e7-a887-aca20e861792","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["i_a_m","deg_n","i_n_m","y_s","deg_b","deg_c","line_id","deg_a","x_s","i_b_m","i_c_m"],"data":{"deg_a":[-19.941099459250353,-19.986780714242464,-19.986780714240368,-19.98596831431716,-20.1422586742578,-20.142258674259352,-20.191262780661965,-20.19126278066196,-20.191262780665035,-20.186722278084417,-19.997440248768335,-19.579217472086523,-19.579217472084604,-19.579217472085197,-19.579217472085123,-20.068342440496064,-20.197388405331488,-20.18672227808808],"deg_b":[-139.9059689812884,-139.92347480996636,-139.92347480996742,-139.92012055782908,-140.0705205998625,-140.0705205998666,-140.11251318466182,-140.1125131846641,-140.1125131846614,-140.1064972211142,-139.96733077343984,-139.52926448262482,-139.52926448262477,-139.5292644826242,-139.52926448262357,-140.0072819710701,-140.1206262476682,-140.10649722111336],"deg_c":[99.98736173382018,99.8653978982162,99.86539789821816,99.85927399847499,99.69184877286716,99.69184877286897,99.62549407651616,99.62549407650955,99.62549407651663,99.62563537608209,99.94527908375728,100.29396570822466,100.29396570822617,100.2939657082248,100.2939657082269,99.79166990398012,99.62530356958791,99.62563537608838],"deg_n":[146.5281813835162,147.05206360493258,147.05206360468816,147.0724289473855,146.9258876454897,146.92588764561387,146.8989897668668,146.89898976708665,146.89898976710776,146.91352627826748,146.39083472723937,147.5710316211432,147.5710316212037,147.57103162125924,147.5710316212359,146.9785477432086,146.87828843006935,146.9135262786213],"i_a_m":[613.0195950677497,318.71060738504985,318.7106073850478,296.1407024670848,213.93888512629192,213.93888512630687,128.64888240955182,128.64888240954227,128.6488824095438,73.88387107238901,22.56990533833079,82.20468473687139,82.20468473687626,82.20468473687542,82.20468473687274,85.29012074527914,54.7650118821347,73.883871 ...

# %%
import numpy as np
from bokeh.io import output_notebook, show
from bokeh.models import ColumnDataSource
from bokeh.io import push_notebook
from bokeh.layouts import gridplot
from bokeh.plotting import figure
output_notebook()

sys1.pq_3pn = s_0
sys1.update()
sys1.pf_eval()
sys1.get_v()
sys1.get_i()

p = figure(width=600, height=300,x_range = [50,-300], y_range = [180,250])
source = ColumnDataSource(sys1.bus_data)
cr = p.circle(source=source, x='y', y='v_an', size=15, color="red", alpha=0.5)
p.circle(source=source, x='y', y='v_bn', size=15, color="green", alpha=0.5)
p.circle(source=source, x='y', y='v_cn', size=15, color="blue", alpha=0.5)
p.line([-300, 50],[231*1.05,231*1.05], color='red', line_width=5)
p.line([-300, 50],[231*0.90,231*0.90], color='blue', line_width=5)
#p.add_tools(HoverTool(renderers=[cr], tooltips=sys1.bus_tooltip))


def update(load_factor=1.0):

    sys1.pq_3pn = load_factor*s_0
    sys1.update()
    sys1.pf_eval()
    sys1.get_v()
    sys1.get_i()
    sys1.bokeh_tools()

    source.data = sys1.bus_data
    push_notebook()

#p_grid = gridplot([[p], [p_2]])
show(p, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7d5df3bd-da10-4b58-b62a-c1d12fc1f07c">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="50df8fac-3203-4bad-aebc-6df2789b4401"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#50df8fac-3203-4bad-aebc-6df2789b4401").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("f708f7ad-e028-41c6-b2db-42fdf6ecaaaf", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("50df8fac-3203-4bad-aebc-6df2789b4401");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '50df8fac-3203-4bad-aebc-6df2789b4401' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"8bdd6ef8-be1c-4db6-ac02-1b9adb8bf838":{"roots":{"references":[{"attributes":{"plot":{"id":"5a6aef66-fa7a-4d66-8c67-f67305cc51d9","subtype":"Figure","type":"Plot"}},"id":"1291a1d1-cecf-4320-a3a7-65e177cfde0c","type":"SaveTool"},{"attributes":{"plot":{"id":"5a6aef66-fa7a-4d66-8c67-f67305cc51d9","subtype":"Figure","type":"Plot"},"ticker":{"id":"a75fe9d0-ccd9-4071-ae51-49dc47d2364f","type":"BasicTicker"}},"id":"2a72b360-9ded-4b70-98a1-9d34936d471b","type":"Grid"},{"attributes":{"data_source":{"id":"126d43a4-9d10-4003-aff5-f2c15984cb0c","type":"ColumnDataSource"},"glyph":{"id":"0b738c67-220b-4d97-a70d-8bc0c2f20569","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"