# %%
import pydss
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
from bokeh.layouts import gridplot
from bokeh.models import ColumnDataSource, HoverTool, CustomJS
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a7093ad6-27d7-4a5b-9b33-08889dc9de65">Loading BokehJS ...</span>
#     </div>

# %%
sys1 = pydss.syst('cigre_lv.json')

# %%
sys1.pf_eval()
sys1.get_v()
sys1.get_i()

# %%
# %timeit sys1.pf_eval()
# Out:
# 1000 loops, best of 3: 1.4 ms per loop

# %%
sys1.bokeh_tools()
line_tooltip = '''
            <div>
            line id = @line_id 
            <table border="1">
                <tr>
                <td>I<sub>a</sub> =  @i_a_m &ang; @deg_a </td>
                </tr>
                <tr>
                <td>I<sub>b</sub> =  @i_b_m &ang; @deg_b </td>
                </tr>
                <tr>
                <td>I<sub>c</sub> =  @i_c_m &ang; @deg_c </td>
                </tr>
            </table>            
            </div>
            '''

bus_tooltip = '''
            <div>
            bus_id = @bus_id 
            <table border="1">
                <tr>
                <td>v<sub>an</sub> =  @v_an  &ang; @deg_an V </td> <td> </td>
                </tr>
                      <tr>
                      <td> </td> <td>v<sub>ab</sub>= @v_ab V</td>
                      </tr>
                <tr>
                <td>v<sub>bn</sub> = @v_bn &ang; @deg_bn V </td><td> </td>
                </tr>
                      <tr>
                      <td> </td><td>v<sub>bc</sub>= @v_bc V</td>
                      </tr>
                <tr>
                <td>v<sub>cn</sub>  = @v_cn &ang; @deg_cn V </td><td> </td>
                </tr> 
                    <tr>
                     <td> </td> <td>v<sub>ca</sub>= @v_ca V</td>
                    </tr>
               <tr>
                <td>v<sub>ng</sub>    = @v_ng &ang; @deg_ng V</td>
              </tr>
            </table>
            </div>
            '''


#p = figure(width=600, height=800, tools=[hover], toolbar_location=None, 
#           title='European LV Network (CIGRE)', x_range=[-200,200], y_range=[-350, 30])

p = figure()
# lines:
source = ColumnDataSource(sys1.line_data)
lin = p.multi_line(source=source, xs='x_s', ys='y_s', color="navy", alpha=0.5, line_width=5)


# buses:
source = ColumnDataSource(sys1.bus_data)
cr = p.circle(source=source, x='x', y='y', size=15, color="navy", alpha=0.5)

#hover = HoverTool(renderer=[lin])
#hover.tooltips = sys1.bus_hover_string
p.add_tools(HoverTool(renderers=[lin], tooltips=line_tooltip))
p.add_tools(HoverTool(renderers=[cr], tooltips=bus_tooltip))
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="843fe5a8-b6fa-4618-86ed-1c14c59d95d8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#843fe5a8-b6fa-4618-86ed-1c14c59d95d8").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("843fe5a8-b6fa-4618-86ed-1c14c59d95d8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '843fe5a8-b6fa-4618-86ed-1c14c59d95d8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"5598e228-9baa-46a8-b574-8a712c284888":{"roots":{"references":[{"attributes":{},"id":"2fc11bea-cdc5-4cbd-9200-908d356652aa","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"3c9bbd58-87ad-4154-b550-6c59824ee080","subtype":"Figure","type":"Plot"},"ticker":{"id":"22ab6603-5aa1-48fe-ac23-a86fbac1faa4","type":"BasicTicker"}},"id":"62bd12df-27cc-49b9-9549-a0ec1242c743","type":"Grid"},{"attributes":{"plot":{"id":"3c9bbd58-87ad-4154-b550-6c59824ee080","subtype":"Figure","type":"Plot"}},"id":"c4a0bb56-9f70-4bb0-a494-a60bcb106768","type":"WheelZoomTool"},{"attributes":{"callback":null},"id":"58371301-f7c8-4873-b0c7-899e5091a234","type":"DataRange1d"},{"attributes":{"data_source":{"id":"fdb8fe66-72dd-4adc-9cd3-7357b26812e0","type":"ColumnDataSource"},"glyph":{"id":"868a34c4-4869-460e-8f40-f702095531d3","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"9484957f-d022-498f-bb40-cdcf7b4fcdd9","type":"Circle"},"selection_glyph":null},"id":"f94aebb3-1858-4824-8739-78b5c94568a5","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"aae73c4d-36c2-4b0f-a9aa-ffb10073a679","type":"PanTool"},{"id":"c4a0bb56-9f70-4bb0-a494-a60bcb106768","type":"WheelZoomTool"},{"id":"f5dcbd32-49d6-46cf-b7c0-de258768a610","type":"BoxZoomTool"},{"id":"b365d1c6-a6d8-4400-839a-9aaec1759bca","type":"SaveTool"},{"id":"fe26e932-1ded-4020-93af-df7b43d32522","type":"ResetTool"},{"id":"e315a95d-ea6a-461c-a638-a4b77ca8c4fe","type":"HelpTool"},{"id":"c5e30f3b-7afc-4a22-8a9d-4987555dccd3","type":"HoverTool"},{"id":"f68cc346-824c-44f4-81ed-567e3bca2459","type":"HoverTool"}]},"id":"d01ff2f0-509c-42a8-91f0-ca58257548e4","type":"Toolbar"},{"attributes":{"formatter":{"id":"8f75c93f-bfae-44ae-984f-3c2c42af99bc","type":"BasicTickFormatter"},"plot":{"id":"3c9bbd58-87ad-4154-b550-6c59824ee080","subtype":"Figure","type":"Plot"},"ticker":{"id":"20872ac8-7b7a-43bb-b2d5-676aaf700e90","type":"BasicTicker"}},"id":"44463c8b-6ee5-4cf6-a601-12abb38170cd","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["deg_cn","x","v_ng","v_cn","v_ca","deg_an","deg_bn","v_an","deg_ng","v_bc","y","v_ab","v_bn","bus_id"],"data":{"bus_id":["R1","R2","R3","R4","R5","R6","R7","R8","R9","R10","R11","R12","R13","R14","R15","R16","R17","R18"],"deg_an":[0.0,-0.1437634183156543,-0.29299886341682496,-0.4412388458788173,-0.5695207317795482,-0.702290709474297,-0.8131144107394233,-0.9274475871495852,-1.0454586680686873,-1.1494280042964944,-0.2622317561459424,-0.30905281835447135,-0.17401621090935881,-0.03603735963286088,0.08464434367702298,-0.5737569020698092,-0.9556660621230197,-0.3975969280306546],"deg_bn":[119.99999999999999,120.29085533087414,120.58442632229537,120.88794240545838,121.2200140170507,121.55317795065784,121.91063215640847,122.26749758187302,122.62374806256753,122.99122066880106,120.61466792264038,121.01616968479195,121.14705402619975,121.28067747231445,121.39745659404976,121.67953682636593,122.71283655650879,124.02463538095918],"deg_cn":[-120.00000000000004,-120.33198792095354,-120.66723223886268,-121.00319561000542,-121.32982400223868,-121.6573702189632,-121.97140690934553,-122.28454442706678,-122.59676800326223,-122.89605742105002,-120.63700837985076,-120.884899165846,-120.76402097603378,-120.64047670282415,-120.53239302425978,-121.55990536511209,-122.5460556157187,-124.2732499009691],"deg_ng":[0.0,4.6468403005122765,4.646840300514829,4.678971244931149,4.804413748697421,4.878227404082136,5.006949709660576,5.097172880581765,5.163921597106337,5.2550041081652115,4.558010959596209,4.2606687917074115,3.83590533245666,3.4045777956267695,3.02956570497869,4.556325087181567,4.970945568145109,-0.573585450191594],"v_ab":[393.0399137399025,389.3759398820716,385.7148196073337,382.282059712158,379.6711316028359,377.06240147454884,375.30912204804616,373.55748987777656,371.8075282450365,370.60932650888196,384.7835546986179,378.31827947813326,374.35629627992614,370.3961677841145,367.00329363 ...

# %%
import numpy as np
from bokeh.models import ColumnDataSource, DataRange1d, Plot, LinearAxis, Grid
from bokeh.models.glyphs import MultiLine
from bokeh.io import curdoc, show

N = 9
x = np.linspace(-2, 2, N)
y = x**2

xpts = np.array([-.09, -.12, .0, .12,  .09])
ypts = np.array([-.1,   .02, .1, .02, -.1])

source = ColumnDataSource(dict(
        xs=[xpts*(1+i/10.0)+xx for i, xx in enumerate(x)],
        ys=[ypts*(1+i/10.0)+yy for i, yy in enumerate(y)],
    )
)

xdr = DataRange1d()
ydr = DataRange1d()

plot = Plot(
    title=None, x_range=xdr, y_range=ydr, plot_width=300, plot_height=300,
    h_symmetry=False, v_symmetry=False, min_border=0, toolbar_location=None)

glyph = MultiLine(xs="xs", ys="ys", line_color="#8073ac", line_width=2)
plot.add_glyph(source, glyph)

xaxis = LinearAxis()
plot.add_layout(xaxis, 'below')

yaxis = LinearAxis()
plot.add_layout(yaxis, 'left')

plot.add_layout(Grid(dimension=0, ticker=xaxis.ticker))
plot.add_layout(Grid(dimension=1, ticker=yaxis.ticker))

curdoc().add_root(plot)
plot.add_tools(HoverTool())
show(plot)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="eb6e6129-5ffc-4dd4-b984-1bd5800732c1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#eb6e6129-5ffc-4dd4-b984-1bd5800732c1").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("eb6e6129-5ffc-4dd4-b984-1bd5800732c1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'eb6e6129-5ffc-4dd4-b984-1bd5800732c1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"7deb07bb-4578-47ee-867b-93d593995209":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"f69d83a5-99a3-4107-9453-cb4a33beb1af","type":"Plot"},"ticker":{"id":"1e4c0eff-a969-42a2-af76-aa329367d5ec","type":"BasicTicker"}},"id":"3b5ff9cd-8908-4212-848f-1e1ad463a107","type":"Grid"},{"attributes":{},"id":"2f2cb525-81c0-4728-aa29-025853d75f21","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["xs","ys"],"data":{"xs":[[-2.09,-2.12,-2.0,-1.88,-1.91],[-1.599,-1.6320000000000001,-1.5,-1.3679999999999999,-1.401],[-1.108,-1.144,-1.0,-0.856,-0.892],[-0.617,-0.656,-0.5,-0.344,-0.383],[-0.126,-0.16799999999999998,0.0,0.16799999999999998,0.126],[0.365,0.32,0.5,0.6799999999999999,0.635],[0.856,0.808,1.0,1.192,1.144],[1.347,1.296,1.5,1.704,1.653],[1.838,1.784,2.0,2.216,2.162]],"ys":[[3.9,4.02,4.1,4.02,3.9],[2.14,2.272,2.36,2.272,2.14],[0.88,1.024,1.12,1.024,0.88],[0.12,0.276,0.38,0.276,0.12],[-0.13999999999999999,0.027999999999999997,0.13999999999999999,0.027999999999999997,-0.13999999999999999],[0.09999999999999998,0.28,0.4,0.28,0.09999999999999998],[0.84,1.032,1.1600000000000001,1.032,0.84],[2.08,2.284,2.42,2.284,2.08],[3.82,4.036,4.18,4.036,3.82]]}},"id":"c290d044-7b7d-41cd-8577-88c31d4deb1f","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"#8073ac"},"line_width":{"value":2},"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":"a7ad73ec-0dc8-4219-9738-86dfd6a08238","type":"MultiLine"},{"attributes":{"below":[{"id":"4b1b7222-5cfd-44b0-960c-ca7723e8cc3b","type":"LinearAxis"}],"h_symmetry":false,"left":[{"id":"3d0bebbc-a458-4907-a33d-62edecf68430","type":"LinearAxis"}],"min_border":0,"plot_height":300,"plot_width":300,"renderers":[{"id":"acf845dd-0e1b-410f-98eb-d154cd6fd1b3","type":"GlyphRenderer"},{"id":"4b1b7222-5cfd-44b0-960c-ca7723e8cc3b","type":"LinearAxis"},{"id":"3d0bebbc-a458-4907-a33d-62edecf68430","type":"LinearAxis"},{"id":"c53cb074-ffd2-4e85-918d-9652040e4944","type":"Grid"},{"id":"3b5ff9cd-8908-4212-848f-1e1ad463a107","type":"Grid"}],"title":null,"tool_events":{"id":"04988c92-5554-473c-ba8e-deb2f595301b","type":"ToolEvents"},"toolbar":{"id":"7a8fe7b3-1ecf-491a-8080-66110a91c73d","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"05b77025-cc17-4406-a990-575b9a66ea97","type":"DataRange1d"},"y_range":{"id":"e27b9825-b075-4371-8a99-ee7caddf4b04","type":"DataRange1d"}},"id":"f69d83a5-99a3-4107-9453-cb4a33beb1af","type":"Plot"},{"attributes":{"callback":null},"id":"05b77025-cc17-4406-a990-575b9a66ea97","type":"DataRange1d"},{"attributes":{"data_source":{"id":"c290d044-7b7d-41cd-8577-88c31d4deb1f","type":"ColumnDataSource"},"glyph":{"id":"a7ad73ec-0dc8-4219-9738-86dfd6a08238","type":"MultiLine"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"acf845dd-0e1b-410f-98eb-d154cd6fd1b3","type":"GlyphRenderer"},{"attributes":{},"id":"04988c92-5554-473c-ba8e-deb2f595301b","type":"ToolEvents"},{"attributes":{"formatter":{"id":"4459afac-415f-49d6-a8e1-66731160ec66","type":"BasicTickFormatter"},"plot":{"id":"f69d83a5-99a3-4107-9453-cb4a33beb1af","type":"Plot"},"ticker":{"id":"1e4c0eff-a969-42a2-af76-aa329367d5ec","type":"BasicTicker"}},"id":"3d0bebbc-a458-4907-a33d-62edecf68430","type":"LinearAxis"},{"attributes":{},"id":"4459afac-415f-49d6-a8e1-66731160ec66","type":"BasicTickFormatter"},{"attributes":{"callback":null,"plot":{"id":"f69d83a5-99a3-4107-9453-cb4a33beb1af","type":"Plot"}},"id":"29bdae0b-3236-41d7-8750-561e82e7d054","type":"HoverTool"},{"attributes":{},"id":"1e4c0eff-a969-42a2-af76-aa329367d5ec","type":"BasicTicker"},{"attributes":{"formatter":{"id":"9551cc3f-ec9d-46a8-8435-2b5a9995b2aa","type":"BasicTickFormatter"},"plot":{"id":"f69d83a5-99a3-4107-9453-cb4a33beb1af","type":"Plot"},"ticker":{"id":"2f2cb525-81c0-4728-aa29-025853d75f21","type":"BasicTicker"}},"id":"4b1b7222-5cfd-44b0-960c-ca7723e8cc3b","type":"LinearAxis"},{"attributes":{"plot":{"id":"f69d83a5-99a3-4107-9453-cb4a33beb1af","type":"Plot"},"ticker":{"id":"2f2cb525-81c0-4 ...
#             var render_items = [{"docid":"7deb07bb-4578-47e

# %%
[xpts*(1+i/10.0)+xx for i, xx in enumerate(x)]
# Out:
# [array([-2.09, -2.12, -2.  , -1.88, -1.91]),
#  array([-1.599, -1.632, -1.5  , -1.368, -1.401]),
#  array([-1.108, -1.144, -1.   , -0.856, -0.892]),
#  array([-0.617, -0.656, -0.5  , -0.344, -0.383]),
#  array([-0.126, -0.168,  0.   ,  0.168,  0.126]),
#  array([ 0.365,  0.32 ,  0.5  ,  0.68 ,  0.635]),
#  array([ 0.856,  0.808,  1.   ,  1.192,  1.144]),
#  array([ 1.347,  1.296,  1.5  ,  1.704,  1.653]),
#  array([ 1.838,  1.784,  2.   ,  2.216,  2.162])]

# %%
import numpy as np

from bokeh.models import ColumnDataSource, DataRange1d, Plot, LinearAxis, Grid
from bokeh.models.glyphs import Segment
from bokeh.io import curdoc, show

N = 9
x = np.linspace(-2, 2, N)
y = x**2

source = ColumnDataSource(dict(
        x_j =[1,2],
        y_j =[1,1],
        x_k =[2,1],
        y_k =[3,3],
    )
)

xdr = DataRange1d()
ydr = DataRange1d()

plot = Plot(
    title=None, x_range=xdr, y_range=ydr, plot_width=300, plot_height=300,
    h_symmetry=False, v_symmetry=False, min_border=0, toolbar_location=None)

glyph = Segment(x0="x_j", y0="y_j", x1="x_k", y1="y_k", line_color="#f4a582", line_width=3)
plot.add_glyph(source, glyph)

xaxis = LinearAxis()
plot.add_layout(xaxis, 'below')

yaxis = LinearAxis()
plot.add_layout(yaxis, 'left')

plot.add_layout(Grid(dimension=0, ticker=xaxis.ticker))
plot.add_layout(Grid(dimension=1, ticker=yaxis.ticker))

curdoc().add_root(plot)

show(plot)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="2f58107f-db33-4b52-816b-9766f70dfb57"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#2f58107f-db33-4b52-816b-9766f70dfb57").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2f58107f-db33-4b52-816b-9766f70dfb57");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2f58107f-db33-4b52-816b-9766f70dfb57' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"31e171c0-dff0-4ff1-a590-2b2642cfaca9":{"roots":{"references":[{"attributes":{},"id":"b0652b5e-daa5-415f-befe-4c62e71b0ed2","type":"ToolEvents"},{"attributes":{},"id":"cf61347f-e375-4700-b7ec-4af4cdc5336f","type":"BasicTicker"},{"attributes":{},"id":"cdfbe3ef-62e3-46e2-a4bf-0cf24d805aad","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto"},"id":"4d57d355-60c1-4e1f-98c0-edf4e95477ee","type":"Toolbar"},{"attributes":{"callback":null},"id":"00026ee9-8b41-433b-ab01-d809db1ed429","type":"DataRange1d"},{"attributes":{"callback":null},"id":"bbecebbc-172e-4aaa-acb9-6c0fad23a505","type":"DataRange1d"},{"attributes":{"plot":{"id":"304b91f9-198c-4e4c-8673-295b465d5ad1","type":"Plot"},"ticker":{"id":"cf61347f-e375-4700-b7ec-4af4cdc5336f","type":"BasicTicker"}},"id":"1ac8b87d-26af-46b9-8b1d-475bd1d5604e","type":"Grid"},{"attributes":{"formatter":{"id":"f143f485-8ce6-4ce9-a25f-719d62f4afb1","type":"BasicTickFormatter"},"plot":{"id":"304b91f9-198c-4e4c-8673-295b465d5ad1","type":"Plot"},"ticker":{"id":"077c78fe-1371-4928-b344-43e0d5346c37","type":"BasicTicker"}},"id":"acb03241-0460-4ccf-aba1-79dfeb42d474","type":"LinearAxis"},{"attributes":{"line_color":{"value":"#f4a582"},"line_width":{"value":3},"x0":{"field":"x_j"},"x1":{"field":"x_k"},"y0":{"field":"y_j"},"y1":{"field":"y_k"}},"id":"a34ec348-b255-4b58-94b7-29d8df5b3aaa","type":"Segment"},{"attributes":{"dimension":1,"plot":{"id":"304b91f9-198c-4e4c-8673-295b465d5ad1","type":"Plot"},"ticker":{"id":"077c78fe-1371-4928-b344-43e0d5346c37","type":"BasicTicker"}},"id":"0221164a-fa72-494f-826b-bc6f4b9f81b2","type":"Grid"},{"attributes":{},"id":"077c78fe-1371-4928-b344-43e0d5346c37","type":"BasicTicker"},{"attributes":{"formatter":{"id":"cdfbe3ef-62e3-46e2-a4bf-0cf24d805aad","type":"BasicTickFormatter"},"plot":{"id":"304b91f9-198c-4e4c-8673-295b465d5ad1","type":"Plot"},"ticker":{"id":"cf61347f-e375-4700-b7ec-4af4cdc5336f","type":"BasicTicker"}},"id":"ef708440-0a05-4b80-ad0a-b9942006255f","type":"LinearAxis"},{"attributes":{"data_source":{"id":"07f4e5b7-fbd4-4a42-8cf8-d776ba20e7d6","type":"ColumnDataSource"},"glyph":{"id":"a34ec348-b255-4b58-94b7-29d8df5b3aaa","type":"Segment"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"48875453-56dc-4362-a793-b6f7d4a4c49d","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"ef708440-0a05-4b80-ad0a-b9942006255f","type":"LinearAxis"}],"h_symmetry":false,"left":[{"id":"acb03241-0460-4ccf-aba1-79dfeb42d474","type":"LinearAxis"}],"min_border":0,"plot_height":300,"plot_width":300,"renderers":[{"id":"48875453-56dc-4362-a793-b6f7d4a4c49d","type":"GlyphRenderer"},{"id":"ef708440-0a05-4b80-ad0a-b9942006255f","type":"LinearAxis"},{"id":"acb03241-0460-4ccf-aba1-79dfeb42d474","type":"LinearAxis"},{"id":"1ac8b87d-26af-46b9-8b1d-475bd1d5604e","type":"Grid"},{"id":"0221164a-fa72-494f-826b-bc6f4b9f81b2","type":"Grid"}],"title":null,"tool_events":{"id":"b0652b5e-daa5-415f-befe-4c62e71b0ed2","type":"ToolEvents"},"toolbar":{"id":"4d57d355-60c1-4e1f-98c0-edf4e95477ee","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"bbecebbc-172e-4aaa-acb9-6c0fad23a505","type":"DataRange1d"},"y_range":{"id":"00026ee9-8b41-433b-ab01-d809db1ed429","type":"DataRange1d"}},"id":"304b91f9-198c-4e4c-8673-295b465d5ad1","type":"Plot"},{"attributes":{"callback":null,"column_names":["y_k","x_k","y_j","x_j"],"data":{"x_j":[1,2],"x_k":[2,1],"y_j":[1,1],"y_k":[3,3]}},"id":"07f4e5b7-fbd4-4a42-8cf8-d776ba20e7d6","type":"ColumnDataSource"},{"attributes":{},"id":"f143f485-8ce6-4ce9-a25f-719d62f4afb1","type":"BasicTickFormatter"}],"root_ids":["304b91f9-198c-4e4c-8673-295b465d5ad1"]},"title":"Bokeh Application","version":"0.12.3"}};
#             var render_items = [{"docid":"31e171c0-dff0-4ff1-a590-2b2642cfaca9","elementid":"2f58107f-db33-4b52-816b-9766f70dfb57","modelid":"304b91f9-198c-4e4c-8673-295b465d5ad1"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#         });
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#
#       if ((window.Bokeh !== undefined) || (force === "1")) {
#         for (var i = 0; i < inline_js.length; i++) {
#           inline_js[i](window.Bokeh);
#         }if (force === "1") {
#           display_loaded();
#         }} else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(run_inline_js, 100);
#       } else if (!window._bokeh_failed_load) {
#         console.log("Bokeh: BokehJS failed to load within specified timeout.");
#         window._bokeh_failed_load = true;
#       } else if (!force) {
#         var cell = $("#2f58107f-db33-4b52-816b-9766f70dfb57").parents('.ce
