# %%
import numpy as np
import numba
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
from bokeh.layouts import gridplot
from bokeh.models import ColumnDataSource, HoverTool, CustomJS
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8a3c9a2a-07bf-4468-89ae-dcfa8d3af7f1">Loading BokehJS ...</span>
#     </div>

# %%
@numba.jit(nopython=True)
def run_eval():
    N_steps = int(1e3)
    N_states = 1
    x = np.zeros((N_states,1))+4
    f = np.zeros((N_states,1))
    X = np.zeros((N_states,N_steps))
    out = np.zeros((3,N_steps))
    #self.out_cplx = np.zeros((72,N_steps),np.complex128)
        
    T = np.zeros((N_steps,1))
    
    obj_w = mech.wind_turbine()
    obj_w.nu = 8.0
    obj_w.tau_r = 100
    dt = 5.0e-3
    t = 0.0
    X[:,0] = x[:,0]
    T[0,0] = t
    for it in range(1,N_steps):  
            t += dt
        
            obj_w.x = x

          
            obj_w.f_eval()
            f = obj_w.f
            
            x = x + dt*f
            
            X[:,it] = x[:,0]
            out[0,it] =obj_w.p_m
            T[it,0] = t
            
    return T,X,out

# %%
T,X,out = run_eval()

# %%
fig = figure(width=600, height=300)
decim = 1
fig.line(T[0:-1:decim,0],X[0,0:-1:decim], line_width=1, color='red')
show(fig)

fig = figure(width=600, height=300)
decim = 1
fig.line(T[0:-1:decim,0],out[0,0:-1:decim], line_width=1, color='red')
show(fig)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a4e8a232-23b3-4ce8-8415-d0dd900cc912"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("a4e8a232-23b3-4ce8-8415-d0dd900cc912").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a4e8a232-23b3-4ce8-8415-d0dd900cc912");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a4e8a232-23b3-4ce8-8415-d0dd900cc912' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2dd5bda0-2c33-4072-8f88-563aa222ed97":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"0dd4edc3-bf4c-4c3a-8b3e-b8c796fa3099","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"c05539e0-e1c0-4b9c-ae06-8fea8c6bee5d","subtype":"Figure","type":"Plot"}},"id":"b4bf6b9a-96b6-402b-a7dd-1d297c5f196e","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"c05539e0-e1c0-4b9c-ae06-8fea8c6bee5d","subtype":"Figure","type":"Plot"}},"id":"5b1ac337-a05f-4293-9445-b5d533256e68","type":"SaveTool"},{"attributes":{"plot":{"id":"c05539e0-e1c0-4b9c-ae06-8fea8c6bee5d","subtype":"Figure","type":"Plot"}},"id":"3bfacff7-dc05-4784-b882-5ce9ee399d2e","type":"PanTool"},{"attributes":{"plot":null,"text":""},"id":"1c17ef9b-c0e1-4552-a64c-548938753016","type":"Title"},{"attributes":{},"id":"4cc77106-5b2f-4bf0-8be7-8492917bab94","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"29b8def0-5303-409f-b13b-cfc14b870a5b","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[999]},"y":{"__ndarray__":"...","dtype":"float64","shape":[999]}}},"id":"50ed632d-28de-4e3e-898a-e69a8c0e74d3","type":"ColumnDataSource"},{"attributes":{},"id":"dd32ddb1-029a-4123-b8d8-0f2d3789d801","type":"BasicTicker"},{"attributes":{"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1c11badf-be8c-4da6-8ee5-e970049c4e8a","type":"Line"},{"attributes":{},"id":"59427760-68fd-47ac-b3f3-54ff1f9ff299","type":"ToolEvents"},{"attributes":{},"id":"cef6717c-2d4f-461b-a75b-a9e92a3f3058","type":"BasicTicker"},{"attributes":{"plot":{"id":"c05539e0-e1c0-4b9c-ae06-8fea8c6bee5d","subtype":"Figure","type":"Plot"}},"id":"4845470f-e8a4-43e4-8f0a-b3311b84cdc3","type":"ResetTool"},{"attributes":{"below":[{"id":"3df5c1a2-48a6-418d-80fa-5e4ea89ed920","type":"LinearAxis"}],"left":[{"id":"318c176d-335c-45d5-bc72-5b42d71a869c","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"3df5c1a2-48a6-418d-80fa-5e4ea89ed920","type":"LinearAxis"},{"id":"020b0060-2a3d-4537-98f8-32cb8a6abf33","type":"Grid"},{"id":"318c176d-335c-45d5-bc72-5b42d71a869c","type":"LinearAxis"},{"id":"2e1b217b-11a2-4608-a5d0-b4d4a7c36e7f","type":"Grid"},{"id":"0dd4edc3-bf4c-4c3a-8b3e-b8c796fa3099","type":"BoxAnnotation"},{"id":"dec4b9c4-6f3e-4b52-ab08-8dff4bf23e28","type":"GlyphRenderer"}],"title":{"id":"1c17ef9b-c0e1-4552-a64c-548938753016","type":"Title"},"tool_events":{"id":"59427760-68fd-47ac-b3f3-54ff1f9ff299","type":"ToolEvents"},"toolbar":{"id":"a3aec187-7eb0-428c-868b-69f83188bd2f","type":"Toolbar"},"x_range":{"id":"ddbd9359-ce07-45eb-a768-ffbf90e4d517","type":"DataRange1d"},"y_range":{"id":"ffc8f10e-91c4-40b4-907c-cf91451170c1","type":"DataRange1d"}},"id":"c05539e0-e1c0-4b9c-ae06-8fea8c6bee5d","subtype":"Figure","type":"Plot"},{"attributes":{"formatter":{"id":"4cc77106-5b2f-4bf0-8be7-8492917bab94","type":"BasicTickFormatter"},"plot":{"id":"c05539e0-e1c0-4b9c-ae06-8fea8c6bee5d","subtype":"Figure","type":"Plot"},"ticker":{"id":"cef6717c-2d4f-461b-a75b-a9e92a3f3058","type":"BasicTicker"}},"id":"318c176d-335c-45d5-bc72-5b42d71a869c","type":"LinearAxis"},{"attributes":{},"id":"421f853a-7cde-477e-86cd-c360c29c0138","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"ddbd9359-ce07-45eb-a768-ffbf90e4d517","type":"DataRange1d"},{"attributes":{"callback":null},"id":"ffc8f10e-91c4-40b4-907c-cf91451170c1","type":"DataRange1d"},{"attributes":{"overlay":{"id":"0dd4edc3-bf4c-4c3a-8b3e-b8c796fa3099","type":"BoxAnnotation"},"plot":{"id":"c05539e0-e1c0-4b9c-ae06-8fea8c6bee5d","subtype":"Figure","type":"Plot"}},"id":"4e6a64c4-91 ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ef0ac3e4-376f-42a0-964f-1d734381ae49"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("ef0ac3e4-376f-42a0-964f-1d734381ae49").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ef0ac3e4-376f-42a0-964f-1d734381ae49");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ef0ac3e4-376f-42a0-964f-1d734381ae49' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3d3717a9-a521-46b6-a670-789f12ffb8e8":{"roots":{"references":[{"attributes":{"formatter":{"id":"384cad33-bf35-43a0-b10c-29028d6bdb1e","type":"BasicTickFormatter"},"plot":{"id":"e34517c0-7677-4e9e-bb8e-812ca8c37229","subtype":"Figure","type":"Plot"},"ticker":{"id":"8a3d15b3-9d6b-45d4-97cc-37430884587a","type":"BasicTicker"}},"id":"d06ca4c5-8ee3-4055-98da-c314a1c3c5cc","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[999]},"y":{"__ndarray__":"...","dtype":"float64","shape":[999]}}},"id":"55b3154f-62be-483f-8862-f65c19189e3c","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"20012fb9-445a-49b7-a28a-0f7e6d65eb57","type":"LinearAxis"}],"left":[{"id":"d06ca4c5-8ee3-4055-98da-c314a1c3c5cc","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"20012fb9-445a-49b7-a28a-0f7e6d65eb57","type":"LinearAxis"},{"id":"c285e833-b9a6-4b8e-9885-6a09feacd6b8","type":"Grid"},{"id":"d06ca4c5-8ee3-4055-98da-c314a1c3c5cc","type":"LinearAxis"},{"id":"bb659bbe-1791-4dad-944b-0164537e0dbf","type":"Grid"},{"id":"633f7cb6-6aaa-4437-b7ca-aa91ac8a3617","type":"BoxAnnotation"},{"id":"1f679415-1859-4857-b9b6-8df57b346bd1","type":"GlyphRenderer"}],"title":{"id":"4773478d-d5a6-464e-90ba-dff8d5b74e94","type":"Title"},"tool_events":{"id":"967fbcd7-b14c-4fbf-a681-fb88e64ce97a","type":"ToolEvents"},"toolbar":{"id":"89d3410c-9dbf-4bc4-930f-8bd5f3389bf2","type":"Toolbar"},"x_range":{"id":"dcfc495c-f9fb-4b83-8300-563046287b94","type":"DataRange1d"},"y_range":{"id":"902614fd-c5fa-424a-ae4e-4c42d7755924","type":"DataRange1d"}},"id":"e34517c0-7677-4e9e-bb8e-812ca8c37229","subtype":"Figure","type":"Plot"},{"attributes":{"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a75aec1b-9e8f-4992-aa41-53860587846e","type":"Line"},{"attributes":{"callback":null},"id":"902614fd-c5fa-424a-ae4e-4c42d7755924","type":"DataRange1d"},{"attributes":{},"id":"8a3d15b3-9d6b-45d4-97cc-37430884587a","type":"BasicTicker"},{"attributes":{},"id":"281781a4-54d1-4be6-8888-b4e038c36d5f","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"55b3154f-62be-483f-8862-f65c19189e3c","type":"ColumnDataSource"},"glyph":{"id":"a75aec1b-9e8f-4992-aa41-53860587846e","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"c34fa02a-c504-43e3-8e78-3ad78225c679","type":"Line"},"selection_glyph":null},"id":"1f679415-1859-4857-b9b6-8df57b346bd1","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"633f7cb6-6aaa-4437-b7ca-aa91ac8a3617","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"e34517c0-7677-4e9e-bb8e-812ca8c37229","subtype":"Figure","type":"Plot"}},"id":"083b593a-c943-44ac-8b77-1fd7bedb41c6","type":"PanTool"},{"attributes":{"dimension":1,"plot":{"id":"e34517c0-7677-4e9e-bb8e-812ca8c37229","subtype":"Figure","type":"Plot"},"ticker":{"id":"8a3d15b3-9d6b-45d4-97cc-37430884587a","type":"BasicTicker"}},"id":"bb659bbe-1791-4dad-944b-0164537e0dbf","type":"Grid"},{"attributes":{"plot":{"id":"e34517c0-7677-4e9e-bb8e-812ca8c37229","subtype":"Figure","type":"Plot"}},"id":"e66acd2d-97a8-4baf-8d07-07188aec8aac","type":"HelpTool"},{"attributes":{"callback":null},"id":"dcfc495c-f9fb-4b83-8300-563046287b94","type":"DataRange1d"},{"attributes":{},"id":"967fbcd7-b14c-4fbf-a681-fb88e64ce97a","type":"ToolEvents"},{"attributes":{"formatter":{"id":"281781a4-54d1-4be6-8888-b4e038c36d5f","type":"BasicTickFormatter"},"plot":{"id":"e34517c0-7677-4e9e-bb8e-812ca8c37229","subtype":"Figure","type":"Plot"},"ticker":{"id":"d2c9c555-4e99-4db3-8a20-b516bcba2bdc","type":"BasicTicker"}},"id":"20012fb9-445a-49b7-a28a-0f7e6d65eb57","type":"LinearAxis"},{"attributes":{"overlay":{"id":"633 ...

# %%
omega_t = np.linspace(0.1,200/10,100)
NU = [4,6,8,10,12,14]
beta = 0.0

fig = figure(width=600, height=300)
decim = 1
for nu in NU:
    fig.line(omega_t,obj_w.aero(omega_t,nu,beta), line_width=1, color='red')
show(fig)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="79ab9a97-afe3-447e-96d9-317b2bddbe38"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#79ab9a97-afe3-447e-96d9-317b2bddbe38").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("79ab9a97-afe3-447e-96d9-317b2bddbe38");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '79ab9a97-afe3-447e-96d9-317b2bddbe38' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"b002c217-665f-46b6-8228-0857efe8c20d":{"roots":{"references":[{"attributes":{},"id":"761b6c3b-4766-4d5f-b434-1f3d1edab6fe","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c27f624e-7470-445d-9109-d0d8b346f752","type":"PanTool"},{"id":"c597a26d-1350-4819-971d-5344eedeb042","type":"WheelZoomTool"},{"id":"aeb159c9-a682-4739-9a88-b0945da84ea1","type":"BoxZoomTool"},{"id":"e1daad12-5500-4ad6-b6bc-9091471f6c53","type":"SaveTool"},{"id":"68027642-1051-421a-aa32-ea612120e15f","type":"ResetTool"},{"id":"0a081c95-6d91-4584-83cd-29e26f81c8d7","type":"HelpTool"}]},"id":"e550be61-75d8-418f-8358-a168265f84b6","type":"Toolbar"},{"attributes":{"dimension":1,"plot":{"id":"67bb060e-9f83-4d3c-9841-a35caf3a78cd","subtype":"Figure","type":"Plot"},"ticker":{"id":"087b2a49-8d95-41be-a080-ef947091ab5d","type":"BasicTicker"}},"id":"e412541a-babe-4e78-b5a1-10f4caf32b34","type":"Grid"},{"attributes":{"callback":null},"id":"24080dec-8173-4837-8159-712b3a38269f","type":"DataRange1d"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"52dfde02-4f9a-4099-a70e-6cd008d91e7b","type":"Line"},{"attributes":{"data_source":{"id":"f533bc90-a7cc-4e9a-ac20-89044ce151e1","type":"ColumnDataSource"},"glyph":{"id":"abf8666d-0555-42bf-83a4-7b2abd121678","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"86dbd7e7-fff3-4942-95ef-b16513383eda","type":"Line"},"selection_glyph":null},"id":"482414c7-bd02-4eaf-9b4a-71379872f7c9","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"67bb060e-9f83-4d3c-9841-a35caf3a78cd","subtype":"Figure","type":"Plot"}},"id":"c27f624e-7470-445d-9109-d0d8b346f752","type":"PanTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0.1,0.301010101010101,0.502020202020202,0.703030303030303,0.904040404040404,1.105050505050505,1.3060606060606061,1.507070707070707,1.708080808080808,1.9090909090909092,2.11010101010101,2.311111111111111,2.512121212121212,2.713131313131313,2.914141414141414,3.1151515151515152,3.316161616161616,3.517171717171717,3.7181818181818183,3.919191919191919,4.1202020202020195,4.32121212121212,4.522222222222221,4.723232323232323,4.924242424242424,5.125252525252525,5.326262626262626,5.5272727272727264,5.728282828282827,5.929292929292929,6.13030303030303,6.331313131313131,6.532323232323232,6.7333333333333325,6.934343434343433,7.135353535353534,7.336363636363636,7.537373737373737,7.738383838383838,7.939393939393939,8.14040404040404,8.341414141414141,8.542424242424241,8.743434343434343,8.944444444444443,9.145454545454545,9.346464646464646,9.547474747474746,9.748484848484848,9.949494949494948,10.15050505050505,10.35151515151515,10.552525252525252,10.753535353535353,10.954545454545453,11.155555555555555,11.356565656565655,11.557575757575757,11.758585858585858,11.959595959595958,12.16060606060606,12.36161616161616,12.562626262626262,12.763636363636362,12.964646464646464,13.165656565656565,13.366666666666665,13.567676767676767,13.768686868686867,13.969696969696969,14.170707070707069,14.37171717171717,14.572727272727272,14.773737373737372,14.974747474747474,15.175757575757574,15.376767676767676,15.577777777777778,15.778787878787877,15.97979797979798,16.18080808080808,16.381818181818183,16.582828282828284,16.783838383838383,16.984848484848484,17.185858585858586,17.386868686868688,17.58787878787879,17.788888888888888,17.98989898989899,18.19090909090909,18.391919191919193,18.592929292929295,18.793939393939393,18.994949494949495,19.195959595959597,19.3969696969697,19.5979797979798,19.7989898989899,20.0],"y":[138.02524491693686,415.4699291439109,692.9146133709181,970.359301236441,1247.806114234945,1525.365978154317,1804.5107310598894,2093.350705231908,2416.6003047629124,2824.2258502800296,3391.5841635766083,4209.9161050834455,5371.688276154428,6956.385251170625,9020.38055758983,11592.002969881753,14671.19455782008,18232.412590005664,22229.360470618 ...

# %%
obj_src.h_eval(00.001)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-c6a54ff24fa4> in <module>()
# ----> 1 obj_src.h_eval(00.001)
#
# NameError: name 'obj_src' is not defined

# %%
@numba.jit(nopython=True)
def run_eval():
    N_steps = int(2e6)
    N_states = 5
    x = np.zeros((N_states,1))
    f = np.zeros((N_states,1))
    X = np.zeros((N_states,N_steps))
    out = np.zeros((4,N_steps))
    #self.out_cplx = np.zeros((72,N_steps),np.complex128)
        
    T = np.zeros((N_steps,1))
    
    obj_pmsm = electric.pmsm_rectifier()
    
    obj_pmsm.v_dc_src = 0.0
       
    dt = 5.0e-6
    t = 0.0
    X[:,0] = x[:,0]
    T[0,0] = t
    for it in range(1,N_steps):  
            t += dt
        
            obj_pmsm.x = x
            obj_pmsm.omega_r = 314/4
 
          
            f[0:5] = obj_pmsm.f_eval(t) 

            x = x + dt*f
            
            X[:,it] = x[:,0]
            out[0:3,it] =obj_pmsm.v_s_abc[:,0]
            out[3,it] =obj_pmsm.tau_r
            T[it,0] = t
            
    return T,X,out

# %%
T,X,out = run_eval()

# %%
fig = figure(width=600, height=300)
decim = 100
fig.line(T[0:-1:decim,0],X[0,0:-1:decim], line_width=1, color='red')
fig.line(T[0:-1:decim,0],X[1,0:-1:decim], line_width=1, color='green')    
fig.line(T[0:-1:decim,0],X[2,0:-1:decim], line_width=1, color='blue')  
show(fig)

fig = figure(width=600, height=300)
decim = 10
fig.line(T[0:-1:decim,0],out[3,0:-1:decim], line_width=1, color='red')
show(fig)
